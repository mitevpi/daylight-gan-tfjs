# %%
# remove sample stuff and clone tf repository
# !rm -rf /content/sample_data
! git clone https://github.com/affinelayer/pix2pix-tensorflow.git
# Out:
# Cloning into 'pix2pix-tensorflow'...
# remote: Enumerating objects: 261, done.
# remote: Total 261 (delta 0), reused 0 (delta 0), pack-reused 261
# Receiving objects: 100% (261/261), 13.33 MiB | 6.70 MiB/s, done.
# Resolving deltas: 100% (103/103), done.

# %%
# add google drive integration for accessing data
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !python /content/pix2pix-tensorflow/pix2pix.py \
  --mode train \
  --output_dir /content/output \
  --max_epochs 200 \
  --input_dir /content/photos \
  --which_direction BtoA
# Out:
# WARNING:tensorflow:From /content/pix2pix-tensorflow/pix2pix.py:540: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# aspect_ratio = 1.0
# batch_size = 1
# beta1 = 0.5
# checkpoint = None
# display_freq = 0
# flip = True
# gan_weight = 1.0
# input_dir = /content/photos
# l1_weight = 100.0
# lab_colorization = False
# lr = 0.0002
# max_epochs = 200
# max_steps = None
# mode = train
# ndf = 64
# ngf = 64
# output_dir = /content/output
# output_filetype = png
# progress_freq = 50
# save_freq = 5000
# scale_size = 286
# seed = 2129746325
# separable_conv = False
# summary_freq = 100
# trace_freq = 0
# which_direction = BtoA
# WARNING:tensorflow:From /content/pix2pix-tensorflow/pix2pix.py:258: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
# !python /content/pix2pix-tensorflow/pix2pix.py --mode export --output_dir /content/export/ --checkpoint /content/output/ --which_direction BtoA

# %%
# !python /content/pix2pix-tensorflow/server/tools/export-checkpoint.py --checkpoint /content/export --output_file /content/pikachu_BtoA.pict
